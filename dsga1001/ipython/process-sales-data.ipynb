# %%
# all imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os.path
import itertools

# %%
colnames = ['borough',
            'neighborhood',
            'building_class_category',
            'tax_class_present', #can appear as "tax class as of final roll date" in some files
            'block',
            'lot',
            'easement',
            'building_class_present', #can appear as "building class as of final roll date" in some files
            'address',
            'apt_number', #can appear as NaN in some files; included in the "address" field
            'zipcode',
            'residential_units',
            'commercial_units',
            'total_units',
            'land_sqft',
            'gross_sqft',
            'year_built',
            'tax_class_at_sale',
            'building_class_at_sale',
            'sale_price',
            'sale_date']

# %%
def read_in_data(filename):
    '''
    read in the file as a dataframe, skipping the first 4 rows.
    standardize the column names
    '''
    df = pd.read_excel(filename, skiprows=[0,1,2,3])
    
    #df = df.rename(str.lower, axis='columns')
    #df = df.rename((lambda colname : colname.rstrip()), axis='columns')
    #df = df.rename(columns={ df.columns[3]: "tax_class_present" }, inplace = True)
    
    df.columns = colnames
    return df

# %%
# read in all files (all years, all boroughs), concatenate as one df, and export to CSV

path = '../data/'
years = list(range(2011, 2020))
boroughs = ['bronx', 'brooklyn', 'manhattan', 'queens', 'statenisland']
#boroughs = ['manhattan']

frames = []

for year, borough in itertools.product(years, boroughs):
    filename = path + str(year) + '_' + borough + '.xls'
    data = read_in_data(filename)
    frames.append(data)

df = pd.concat(frames)

display(df)
print(df.shape) #confirm 21 columns
# Out:
#       borough               neighborhood  \
# 0           2  BATHGATE
# 1           2  BATHGATE
# 2           2  BATHGATE
# 3           2  BATHGATE
# 4           2  BATHGATE
# ...       ...                        ...
# 8366        5                    WOODROW
# 8367        5                    WOODROW
# 8368        5                    WOODROW
# 8369        5                    WOODROW
# 8370        5                    WOODROW
#
#                            building_class_category tax_class_present  block  \
# 0     01  ONE FAMILY HOMES                                         1   3037
# 1     01  ONE FAMILY HOMES                                         1   3039
# 2     01  ONE FAMILY HOMES                                         1   3046
# 3     01  ONE FAMILY HOMES                                         1   3048
# 4     01  ONE FAMILY HOMES                                         1   3053
# ...                                            ...               ...    ...
# 8366                       02 TWO FAMILY DWELLINGS                 1   7355
# 8367                    05 TAX CLASS 1 VACANT LAND                 1   7094
# 8368                    05 TAX CLASS 1 VACANT LAND                 1   7094
# 8369                    05 TAX CLASS 1 VACANT LAND                1B   7349
# 8370                        06 TAX CLASS 1 - OTHER                 1   7267
#
#       lot easement building_class_present  \
# 0      42                              A1
# 1      64                              A1
# 2      34                              A1
# 3      28                              A1
# 4     103                              A1
# ...   ...      ...                    ...
# 8366   95      NaN                     B9
# 8367   48      NaN                     B9
# 8368   49      NaN                     B9
# 8369   28      NaN                     V0
# 8370  129      NaN                     G0
#
#                                         address    apt_number  ...  \
# 0     4428 PARK AVENUE                                         ...
# 1     467 EAST 185 STREET                                      ...
# 2     2085 BATHGATE AV                                         ...
# 3     540 EAST 182ND STREET                                    ...
# 4     2327 BASSFORD AVENUE                                     ...
# ...                                         ...           ...  ...
# 8366                        115 AMBASSADOR LANE           NaN  ...
# 8367                         108 BERKSHIRE LANE           NaN  ...
# 8368                          35 WILTSHIRE LANE           NaN  ...
# 8369                             N/A QUAIL LANE           NaN  ...
# 8370                           22 CLAY PIT ROAD           NaN  ...
#
#       residential_units  commercial_units  total_units  land_sqft  gross_sqft  \
# 0                   1.0               0.0          1.0     3525.0      1340.0
# 1                   1.0               0.0          1.0     1667.0      1296.0
# 2                   1.0               0.0          1.0     2060.0      1629.0
# 3                   1.0               0.0          1.0     1209.0      1048.0
# 4                   1.0               0.0          1.0      913.0      1248.0
# ...                 ...               ...          ...        ...         ...
# 8366                2.0               0.0          2.0     8846.0      1710.0
# 8367                2.0               0.0          2.0        0.0         0.0
# 8368                2.0               0.0          2.0        0.0         0.0
# 8369                0.0               0.0          0.0     2640.0         0.0
# 8370                0.0               0.0          0.0     7920.0         0.0
#
#       year_built  tax_class_at_sale  building_class_at_sale sale_price  \
# 0         1899.0                  1                      A1          0
# 1         1910.0                  1                      A1     329000
# 2         1899.0                  1                      A1     288500
# 3         1901.0                  1                      A1     122500
# 4         1901.0                  1                      A1         10
# ...          ...                ...                     ...        ...
# 8366      2001.0                  1                      B9     637500
# 8367      2018.0                  1                      V0     599701
# 8368      2018.0                  1                      V0     896060
# 8369         NaN                  1                      V0      26000
# 8370      2011.0                  1                      G0          0
#
#       sale_date
# 0    2011-02-08
# 1    2011-01-19
# 2    2011-06-29
# 3    2011-03-21
# 4    2011-08-25
# ...         ...
# 8366 2019-08-20
# 8367 2019-04-24
# 8368 2019-04-22
# 8369 2019-08-22
# 8370 2019-05-22
#
# [773881 rows x 21 columns]

# %%
exportfile = '../data/sales_combined.csv'
df.to_csv(exportfile, index=False)

# assert that the exported CSV file exists
os.path.isfile(exportfile)
# Out:
# True

# %%
# check the newly produced CSV file
combined_data = pd.read_csv(exportfile)

display(combined_data)
print(combined_data.shape)
# Out:
# /anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3146: DtypeWarning: Columns (6) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#         borough               neighborhood  \
# 0             2  BATHGATE
# 1             2  BATHGATE
# 2             2  BATHGATE
# 3             2  BATHGATE
# 4             2  BATHGATE
# ...         ...                        ...
# 773876        5                    WOODROW
# 773877        5                    WOODROW
# 773878        5                    WOODROW
# 773879        5                    WOODROW
# 773880        5                    WOODROW
#
#                              building_class_category tax_class_present  block  \
# 0       01  ONE FAMILY HOMES                                         1   3037
# 1       01  ONE FAMILY HOMES                                         1   3039
# 2       01  ONE FAMILY HOMES                                         1   3046
# 3       01  ONE FAMILY HOMES                                         1   3048
# 4       01  ONE FAMILY HOMES                                         1   3053
# ...                                              ...               ...    ...
# 773876                       02 TWO FAMILY DWELLINGS                 1   7355
# 773877                    05 TAX CLASS 1 VACANT LAND                 1   7094
# 773878                    05 TAX CLASS 1 VACANT LAND                 1   7094
# 773879                    05 TAX CLASS 1 VACANT LAND                1B   7349
# 773880                        06 TAX CLASS 1 - OTHER                 1   7267
#
#         lot easement building_class_present  \
# 0        42                              A1
# 1        64                              A1
# 2        34                              A1
# 3        28                              A1
# 4       103                              A1
# ...     ...      ...                    ...
# 773876   95      NaN                     B9
# 773877   48      NaN                     B9
# 773878   49      NaN                     B9
# 773879   28      NaN                     V0
# 773880  129      NaN                     G0
#
#                                           address    apt_number  ...  \
# 0       4428 PARK AVENUE                                         ...
# 1       467 EAST 185 STREET                                      ...
# 2       2085 BATHGATE AV                                         ...
# 3       540 EAST 182ND STREET                                    ...
# 4       2327 BASSFORD AVENUE                                     ...
# ...                                           ...           ...  ...
# 773876                        115 AMBASSADOR LANE           NaN  ...
# 773877                         108 BERKSHIRE LANE           NaN  ...
# 773878                          35 WILTSHIRE LANE           NaN  ...
# 773879                             N/A QUAIL LANE           NaN  ...
# 773880                           22 CLAY PIT ROAD           NaN  ...
#
#         residential_units  commercial_units  total_units  land_sqft  \
# 0                     1.0               0.0          1.0     3525.0
# 1                     1.0               0.0          1.0     1667.0
# 2                     1.0               0.0          1.0     2060.0
# 3                     1.0               0.0          1.0     1209.0
# 4                     1.0               0.0          1.0      913.0
# ...                   ...               ...          ...        ...
# 773876                2.0               0.0          2.0     8846.0
# 773877                2.0               0.0          2.0        0.0
# 773878                2.0               0.0          2.0        0.0
# 773879                0.0               0.0          0.0     2640.0
# 773880                0.0               0.0          0.0     7920.0
#
#         gross_sqft  year_built  tax_class_at_sale  building_class_at_sale  \
# 0           1340.0      1899.0                  1                      A1
# 1           1296.0      1910.0                  1                      A1
# 2           1629.0      1899.0                  1                      A1
# 3           1048.0      1901.0                  1                      A1
# 4           1248.0      1901.0                  1                      A1
# ...            ...         ...                ...                     ...
# 773876      1710.0      2001.0                  1                      B9
# 773877         0.0      2018.0                  1                      V0
# 773878         0.0      2018.0                  1                      V0
# 773879         0.0         NaN                  1                      V0
# 773880         0.0      2011.0                  1                      G0
#
#        sale_price   sale_date
# 0               0  2011-02-08
# 1          329000  2011-01-19
# 2          288500  2011-06-29
# 3          122500  2011-03-21
# 4              10  2011-08-25
# ...           ...         ...
# 773876     637500  2019-08-20
# 773877     599701  2019-04-24
# 773878     896060  2019-04-22
# 773879      26000  2019-08-22
# 773880          0  2019-05-22
#
# [773881 rows x 21 columns]
# (773881, 21)

# %% [markdown]
# **Unused cells**

# %%
# df1 = read_in_data('../data/2011_manhattan.xls')
# df2 = read_in_data('../data/2012_manhattan.xls')
# df3 = read_in_data('../data/2013_manhattan.xls')
# df4 = read_in_data('../data/2014_manhattan.xls')
# df5 = read_in_data('../data/2015_manhattan.xls')
# df6 = read_in_data('../data/2016_manhattan.xls')
# df7 = read_in_data('../data/2017_manhattan.xls')
# df8 = read_in_data('../data/2018_manhattan.xls')
# df9 = read_in_data('../data/2019_manhattan.xls')

# frames = [df1, df2, df3, df4, df5, df6, df7, df8, df9]
# df = pd.concat(frames)
