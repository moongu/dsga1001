# %% [markdown]
# # Modeling: Support Vector Regressor

# %%
# all imports

import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split, GridSearchCV
# TODO: import additional sklearn dependencies here

import matplotlib.pyplot as plt
# %matplotlib inline

# notebook settings
from IPython.display import display
pd.options.display.max_columns = None

# %%
# path for exporting and importing data files
above = '../../../'

# %%
# load in the data
# TODO: replace this with loading in finalized train-test split sets
# data = pd.read_pickle(path + 'post_eda.pkl')
data = pd.read_pickle(above + 'd_PCmd.pkl')
#data = data.sample(frac = .01)
#data.drop(["s_total_units"], axis =1, inplace=True)
display(data)
# Out:
#         s_borough  s_zipcode  s_year_built  s_building_class_at_sale  \
# 0               2    10458.0        1910.0                       5.0
# 1               2    10469.0        1930.0                       3.0
# 2               2    10469.0        1960.0                       3.0
# 3               2    10466.0        1950.0                       3.0
# 4               2    10458.0        1910.0                       5.0
# ...           ...        ...           ...                       ...
# 103377          5    10309.0        1992.0                       3.0
# 103378          5    10309.0        2017.0                       3.0
# 103379          5    10309.0        2017.0                       3.0
# 103380          5    10309.0        2017.0                       3.0
# 103381          5    10309.0        1993.0                       3.0
#
#         s_sale_price  v_stories  v_fullval  v_nta  a_count  c_count  \
# 0             329000        2.0     365000   45.0     8448     8671
# 1             255000        2.0     333000   82.0     8448     8671
# 2             330000        2.0     343000   82.0     8448     8671
# 3             360000        2.0     340000  101.0     8448     8671
# 4             240000        2.5     362000  168.0     8448     8671
# ...              ...        ...        ...    ...      ...      ...
# 103377        435000        3.0     354000  105.0      936     1866
# 103378        739388        1.0     729000   36.0      936     1866
# 103379        631213        1.0     191000  172.0      936     1866
# 103380        636304        1.0     184000  172.0      936     1866
# 103381        585000        3.0     472000  172.0      936     1866
#
#         imputed_land_area    m_PC_1    m_PC_2    m_PC_3    m_PC_4    m_PC_5  \
# 0                  1667.0 -4.888827  5.499321  0.268284 -0.884285  0.379745
# 1                  1900.0 -4.888827  5.499321  0.268284 -0.884285  0.379745
# 2                  2349.0 -4.888827  5.499321  0.268284 -0.884285  0.379745
# 3                  2589.0 -4.888827  5.499321  0.268284 -0.884285  0.379745
# 4                  3160.0 -4.888827  5.499321  0.268284 -0.884285  0.379745
# ...                   ...       ...       ...       ...       ...       ...
# 103377             1294.0  5.975158  1.746840  0.793994  0.903742  0.534116
# 103378             4427.0  5.975158  1.746840  0.793994  0.903742  0.534116
# 103379             2935.0  5.975158  1.746840  0.793994  0.903742  0.534116
# 103380             2837.0  5.975158  1.746840  0.793994  0.903742  0.534116
# 103381             3000.0  5.975158  1.746840  0.793994  0.903742  0.534116
#
#           m_PC_6    m_PC_7    m_PC_8    m_PC_9   m_PC_10   m_PC_11   m_PC_12  \
# 103381  1.414193  1.464058  0.841560 -1.601767  0.321398 -0.669745 -0.473712
#
#          d_PC_11   d_PC_12   d_PC_13   d_PC_14   d_PC_15   d_PC_16   d_PC_17  \
# 0       1.313953 -0.747780  0.415575  1.309033  1.204255 -0.287734  1.021703
# 1       1.313953 -0.747780  0.415575  1.309033  1.204255 -0.287734  1.021703
# 2       1.313953 -0.747780  0.415575  1.309033  1.204255 -0.287734  1.021703
# 3       1.313953 -0.747780  0.415575  1.309033  1.204255 -0.287734  1.021703
# 4       1.313953 -0.747780  0.415575  1.309033  1.204255 -0.287734  1.021703
# ...          ...       ...       ...       ...       ...       ...       ...
# 103377  0.185505  0.645669  0.407699  0.335506 -0.218477  0.404786  0.169710
# 103378  0.185505  0.645669  0.407699  0.335506 -0.218477  0.404786  0.169710
# 103379  0.185505  0.645669  0.407699  0.335506 -0.218477  0.404786  0.169710
# 103380  0.185505  0.645669  0.407699  0.335506 -0.218477  0.404786  0.169710
# 103381  0.185505  0.645669  0.407699  0.335506 -0.218477  0.404786  0.169710
#
#          d_PC_18   d_PC_19   d_PC_20
# 0      -0.094521  0.972989 -0.080561
# 1      -0.094521  0.972989 -0.080561
# 2      -0.094521  0.972989 -0.080561
# 3      -0.094521  0.972989 -0.080561
# 4      -0.094521  0.972989 -0.080561
# ...          ...       ...       ...
# 103377  0.270138  0.189550 -0.033030
# 103378  0.270138  0.189550 -0.033030
# 103379  0.270138  0.189550 -0.033030
# 103380  0.270138  0.189550 -0.033030
# 103381  0.270138  0.189550 -0.033030
#
# [103382 rows x 46 columns]

# %%
# TODO: remove this when we are loading in finalized train-test split sets instead
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
# split the data into X and Y
X = data.drop('s_sale_price', axis=1)
y = data['s_sale_price']
X = scaler.fit_transform(X)

# split the data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %% [markdown]
# ## Fit the model with default hyperparams

# %%
from sklearn import svm
from sklearn import metrics

# Create a SVM Regressor
reg = svm.SVR()

# %%
# Train the model using the training sets 
reg.fit(X_train, y_train)
# Out:
# SVR()

# %%
# Predicting Test data with the model
y_test_pred = reg.predict(X_test)

# %%
X_train.shape[0]
# Out:
# 82705

# %%
acc_xgb = metrics.r2_score(y_test, y_test_pred)
print('R^2:', acc_xgb)
print('Adjusted R^2:',1 - (1-metrics.r2_score(y_test, y_test_pred))*(len(y_test)-1)/(len(y_test)-X_test.shape[1]-1))
print('MAE:',metrics.mean_absolute_error(y_test, y_test_pred))
print('MSE:',metrics.mean_squared_error(y_test, y_test_pred))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)))
# Out:
# R^2: -0.03867541072098968
# Adjusted R^2: -0.040940952550394316
# MAE: 405769.1566796454
# MSE: 1662077975763.2727
# RMSE: 1289216.0314560444

# %% [markdown]
# ## Search for the most performant set of hyperparams

# %%
# TODO
