# %% [markdown]
# # Combine Sales and Valuation datasets into one dataframe

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
import itertools
import datetime

from IPython.display import display
pd.options.display.max_columns = None

# %%
# make sure your dir structure looks like this:
# dsga1001/ (git repo) --> dsga1001/ --> ipython/ --> .ipynb files
# dsga1001-data/ --> .pkl files

# path for exporting and importing data files
path = '../../../dsga1001-data/'

# %% [markdown]
# ## Read in the Sales and Valuation dataframes

# %%
# Read the datasets into dataframes
sales = pd.read_pickle(path + 'sales.pkl')
valuation = pd.read_pickle(path + 'valuation.pkl')

# %%
display(sales)
# Out:
#       borough               neighborhood building_class_category  block  lot  \
# 1           2  BATHGATE                                       01   3039   64
# 2           2  BATHGATE                                       01   3046   34
# 3           2  BATHGATE                                       01   3048   28
# 4           2  BATHGATE                                       01   3053  103
# 5           2  BATHGATE                                       02   2929  128
# ...       ...                        ...                     ...    ...  ...
# 8364        5                    WOODROW                      02   7355   85
# 8366        5                    WOODROW                      02   7355   95
# 8367        5                    WOODROW                      05   7094   48
# 8368        5                    WOODROW                      05   7094   49
# 8369        5                    WOODROW                      05   7349   28
#
#                                         address    apt_number  zipcode  \
# 1     467 EAST 185 STREET                                      10458.0
# 2     2085 BATHGATE AV                                         10457.0
# 3     540 EAST 182ND STREET                                    10457.0
# 4     2327 BASSFORD AVENUE                                     10458.0
# 5     559 CLAREMONT PARKWAY                                    10457.0
# ...                                         ...           ...      ...
# 8364                        104 AMBASSADOR LANE           NaN  10309.0
# 8366                        115 AMBASSADOR LANE           NaN  10309.0
# 8367                         108 BERKSHIRE LANE           NaN  10309.0
# 8368                          35 WILTSHIRE LANE           NaN  10309.0
# 8369                             N/A QUAIL LANE           NaN  10309.0
#
#       residential_units  commercial_units  total_units  land_sqft  gross_sqft  \
# 1                   1.0               0.0          1.0     1667.0      1296.0
# 2                   1.0               0.0          1.0     2060.0      1629.0
# 3                   1.0               0.0          1.0     1209.0      1048.0
# 4                   1.0               0.0          1.0      913.0      1248.0
# 5                   2.0               0.0          2.0     2361.0      2394.0
# ...                 ...               ...          ...        ...         ...
# 8364                2.0               0.0          2.0     2730.0      2565.0
# 8366                2.0               0.0          2.0     8846.0      1710.0
# 8367                2.0               0.0          2.0        0.0         0.0
# 8368                2.0               0.0          2.0        0.0         0.0
# 8369                0.0               0.0          0.0     2640.0         0.0
#
#       year_built  tax_class_at_sale building_class_at_sale  sale_price  \
# 1         1910.0                  1                     A1      329000
# 2         1899.0                  1                     A1      288500
# 3         1901.0                  1                     A1      122500
# 4         1901.0                  1                     A1          10
# 5         1995.0                  1                     B1      365000
# ...          ...                ...                    ...         ...
# 8364      2001.0                  1                     B9      625000
# 8366      2001.0                  1                     B9      637500
# 8367      2018.0                  1                     V0      599701
# 8368      2018.0                  1                     V0      896060
# 8369         NaN                  1                     V0       26000
#
#       sale_date
# 1    2011-01-19
# 2    2011-06-29
# 3    2011-03-21
# 4    2011-08-25
# 5    2011-07-13
# ...         ...
# 8364 2019-07-30
# 8366 2019-08-20
# 8367 2019-04-24
# 8368 2019-04-22
# 8369 2019-08-22
#
# [491304 rows x 18 columns]

# %%
display(valuation)
# Out:
#                BBLE BLDGCL  LTFRONT  LTDEPTH  STORIES  FULLVAL  BLDFRONT  \
# 0        1010401210     R4        0        0     35.0   113465       327
# 1        1008901282     R4        0        0     19.0   135599         0
# 2        1009681288     R4        0        0     37.0   222481         0
# 3        1008701611     R4      244      425     27.0   172555         0
# 4        1010381112     R4        0        0     43.0   175784       100
# ...             ...    ...      ...      ...      ...      ...       ...
# 9845849  1006951519     R4        0        0     14.0   131716         0
# 9845852  1007650020     C4       25      103      5.0   782000        92
# 9845854  1007640075     C4       25       93      4.0  3340000        55
# 9845855  1006260047     S4       24       88      4.0  6460000        40
# 9845856  1007221077     R4      150       98      9.0   405790         0
#
#             YEAR   Latitude  Longitude  \
# 0        2010/11  40.762988 -73.987791
# 1        2010/11  40.746162 -73.979129
# 2        2010/11  40.745156 -73.972500
# 3        2010/11  40.734072 -73.988713
# 4        2010/11  40.761262 -73.987572
# ...          ...        ...        ...
# 9845849  2010/11  40.748400 -74.005836
# 9845852  2010/11  40.739672 -74.000173
# 9845854  2010/11  40.740141 -74.002227
# 9845855  2010/11  40.738143 -74.004471
# 9845856  2010/11  40.748110 -74.001223
#
#                                                 NTA
# 0                                           Clinton
# 1                              Murray Hill-Kips Bay
# 2                           Turtle Bay-East Midtown
# 3                                          Gramercy
# 4                                           Clinton
# ...                                             ...
# 9845849  Hudson Yards-Chelsea-Flatiron-Union Square
# 9845852  Hudson Yards-Chelsea-Flatiron-Union Square
# 9845854  Hudson Yards-Chelsea-Flatiron-Union Square
# 9845855                                West Village
# 9845856  Hudson Yards-Chelsea-Flatiron-Union Square
#
# [8501754 rows x 11 columns]

# %% [markdown]
# ## Standardize column names

# %%
# Change the column names to be lower case, and replace white space with underscores
valuation.rename(columns=lambda x: x.lower().replace(" ", "_"), inplace=True)
sales.rename(columns=lambda x: x.lower().replace(" ", "_"), inplace=True)

# %%
# add prefix to all cols depending on dataset
sales.rename(columns=lambda x: 's_' + x, inplace=True)
valuation.rename(columns=lambda x: 'v_' + x, inplace=True)

# %%
sales.columns
# Out:
# Index(['s_borough', 's_neighborhood', 's_building_class_category', 's_block',
#        's_lot', 's_address', 's_apt_number', 's_zipcode',
#        's_residential_units', 's_commercial_units', 's_total_units',
#        's_land_sqft', 's_gross_sqft', 's_year_built', 's_tax_class_at_sale',
#        's_building_class_at_sale', 's_sale_price', 's_sale_date'],
#       dtype='object')

# %%
valuation.columns
# Out:
# Index(['v_bble', 'v_bldgcl', 'v_ltfront', 'v_ltdepth', 'v_stories',
#        'v_fullval', 'v_bldfront', 'v_year', 'v_latitude', 'v_longitude',
#        'v_nta'],
#       dtype='object')

# %% [markdown]
# ## Create Index
#
# The BBL number is going to be ideal for indexing as it is used for this purpose by the NYC databases.
#
# https://www.pincusco.com/data-dictionary/bbl-also-known-as-borough-block-and-lot-or-property-id/
# https://www.propertyshark.com/Real-Estate-Reports/2018/12/13/all-you-need-to-know-about-nycs-bbl/#:~:text=BBL%20stands%20for%20borough%2C%20block,1%20%3D%20Manhattan

# %%
# for valuation data, BBLE is the same as BBL for non-easement rows -- rename as 'v_bbl'
valuation.rename(columns={'v_bble':'v_bbl'}, inplace=True)

# %%
# Add the BBL column for indexing to the sales data
sales['s_block'] = sales['s_block'].astype(str).map(lambda x : x.zfill(5))
sales['s_lot'] = sales['s_lot'].astype(str).map(lambda x : x.zfill(4))

sales['s_bbl'] = sales['s_borough'].astype(str) + sales['s_block'].astype(str) + sales['s_lot'].astype(str)

# %%
# create a binned year col in sales df (cutoff: July 1)

# first, convert string into datetime
# if the date in a given year N is past July 1st, then mark it as 'N/N+1'
# otherwise, mark as 'N-1/N'

def bin_year(sale_date):
    year = sale_date.year
    if datetime.date(year, 7, 1) <= sale_date:
        return str(year) + '/' + str(year + 1)[-2:]
    else:
        return str(year - 1) + '/' + str(year)[-2:]

# save that result string into a new col called 'year' (index col -- should be same as valuation col)
sales['s_year'] = pd.to_datetime(sales['s_sale_date']).map(lambda x : bin_year(x))

# %%
# print how many unique BBLs we have in sales and valuation datasets
print(sales.s_bbl.nunique())
print(valuation.v_bbl.nunique())
# Out:
# 294796
# 991041

# %% [markdown]
# -------------------------------------------------------------------------------

# %% [markdown]
# ## Merging

# %%
inner_merged = pd.merge(left=sales, right=valuation, how='inner', left_on=['s_bbl', 's_year'], right_on=['v_bbl', 'v_year'])

# %%
# drop duplicate index cols
inner_merged = inner_merged.drop(['v_bbl', 'v_year'], axis=1)

# %%
display(inner_merged)
# Out:
#         s_borough             s_neighborhood s_building_class_category  \
# 0               2  BATHGATE                                         01
# 1               2  BATHGATE                                         01
# 2               2  BATHGATE                                         01
# 3               2  BATHGATE                                         01
# 4               2  BATHGATE                                         02
# ...           ...                        ...                       ...
# 425729          5                    WOODROW                        02
# 425730          5                    WOODROW                        02
# 425731          5                    WOODROW                        02
# 425732          5                    WOODROW                        02
# 425733          5                    WOODROW                        02
#
#        s_block s_lot                                  s_address  s_apt_number  \
# 0        03039  0064  467 EAST 185 STREET
# 1        03046  0034  2085 BATHGATE AV
# 2        03048  0028  540 EAST 182ND STREET
# 3        03053  0103  2327 BASSFORD AVENUE
# 4        02929  0128  559 CLAREMONT PARKWAY
# ...        ...   ...                                        ...           ...
# 425729   07316  0084                            57 DARNELL LANE           NaN
# 425730   07317  0119                             73 ROBIN COURT           NaN
# 425731   07349  0004                           51 PHEASANT LANE           NaN
# 425732   07349  0035                              33 QUAIL LANE           NaN
# 425733   07351  0022                          22 HERRICK AVENUE           NaN
#
#         s_zipcode  s_residential_units  s_commercial_units  s_total_units  \
# 0         10458.0                  1.0                 0.0            1.0
# 1         10457.0                  1.0                 0.0            1.0
# 2         10457.0                  1.0                 0.0            1.0
# 3         10458.0                  1.0                 0.0            1.0
# 4         10457.0                  2.0                 0.0            2.0
# ...           ...                  ...                 ...            ...
# 425729    10309.0                  2.0                 0.0            2.0
# 425730    10309.0                  2.0                 0.0            2.0
# 425731    10309.0                  2.0                 0.0            2.0
# 425732    10309.0                  2.0                 0.0            2.0
# 425733    10309.0                  2.0                 0.0            2.0
#
#         s_land_sqft  s_gross_sqft  s_year_built  s_tax_class_at_sale  \
# 0            1667.0        1296.0        1910.0                    1
# 1            2060.0        1629.0        1899.0                    1
# 2            1209.0        1048.0        1901.0                    1
# 3             913.0        1248.0        1901.0                    1
# 4            2361.0        2394.0        1995.0                    1
# ...             ...           ...           ...                  ...
# 425729       2311.0        1500.0        1995.0                    1
# 425730       4125.0        2160.0        1994.0                    1
# 425731       2123.0        1850.0        1998.0                    1
# 425732       2255.0        2377.0        1998.0                    1
# 425733       4000.0        2400.0        2000.0                    1
#
#        s_building_class_at_sale  s_sale_price s_sale_date       s_bbl  \
# 0                            A1        329000  2011-01-19  2030390064
# 1                            A1        288500  2011-06-29  2030460034
# 2                            A1        122500  2011-03-21  2030480028
# 3                            A1            10  2011-08-25  2030530103
# 4                            B1        365000  2011-07-13  2029290128
# ...                         ...           ...         ...         ...
# 425729                       B2        620000  2019-06-20  5073160084
# 425730                       B2        625000  2019-05-21  5073170119
# 425731                       B9        670000  2019-02-22  5073490004
# 425732                       B9        640000  2019-03-08  5073490035
# 425733                       B2        917000  2019-03-01  5073510022
#
#          s_year v_bldgcl  v_ltfront  v_ltdepth  v_stories  v_fullval  \
# 0       2010/11       A1         16        100        2.0     365000
# 1       2010/11       A1         22         93        2.7     322000
# 2       2010/11       A1         15         80        2.0     299000
# 3       2011/12       A1         20         45        2.0     376000
# 4       2011/12       B1          0         42        3.0     403000
# ...         ...      ...        ...        ...        ...        ...
# 425729  2018/19       B2         26         88        2.0     518000
# 425730  2018/19       B2         25        165        3.0     527000
# 425731  2018/19       B9         23         91        2.0     581000
# 425732  2018/19       B9         27         83        3.0     517000
# 425733  2018/19       B2         40        100        2.0     745000
#
#         v_bldfront  v_latitude  v_longitude  \
# 0               44   40.856635   -73.892647
# 1               37   40.850613   -73.895064
# 2               30   40.853004   -73.892627
# 3               30   40.855847   -73.891755
# 4               42   40.837745   -73.900144
# ...            ...         ...          ...
# 425729          44   40.536003   -74.223213
# 425730          40   40.536140   -74.222012
# 425731          52   40.532829   -74.222422
# 425732          40   40.532390   -74.221234
# 425733          47   40.530765   -74.218448
#
#                                          v_nta
# 0                           Claremont-Bathgate
# 1                           Claremont-Bathgate
# 2                                 East Tremont
# 3                           Claremont-Bathgate
# 4                           Claremont-Bathgate
# ...                                        ...
# 425729  Charleston-Richmond Valley-Tottenville
# 425730  Charleston-Richmond Valley-Tottenville
# 425731  Charleston-Richmond Valley-Tottenville
# 425732  Charleston-Richmond Valley-Tottenville
# 425733  Charleston-Richmond Valley-Tottenville
#
# [425734 rows x 29 columns]

# %%
# save the merged df
inner_merged.to_pickle(path + 'merged-sales-val.pkl')
