# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
import itertools
import datetime

from IPython.display import display
pd.options.display.max_columns = None
above = '../../../'
# val_file = above + 'assessment_og.pkl'
# valuation = pd.read_pickle(val_file)
inner_file = above + 'merged-sales-valuation-macroeconomic.pkl'
inner = pd.read_pickle(inner_file)

# %%
moon = inner
moon.shape
# Out:
# (340540, 80)

# %%
hmm = pd.read_pickle(above + 'merged-sales-valuation-macroeconomic_pg.pkl')
hmm.drop(["S_easement"], axis=1, inplace=True)
# hmm.to_csv(above + 'merged-sales-valuation-macroeconomic_pg.csv')

# %%
# Whats the mean and median difference
print(f' Mean difference is {np.round(hmm["S_sale_price"].mean() - hmm["v_fullval"].mean(), 0)}')
print(f' Median difference is {hmm["S_sale_price"].median() - hmm["v_fullval"].median()}')
# Out:
#  Mean difference is -6338051.0
#  Median difference is -37000.0

# %%
hmm.columns == moon.columns
# Out:
# array([ True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#        False, False, False,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True,  True,
#         True,  True,  True,  True,  True,  True,  True,  True])

# %%
hmm.iloc[[1,2], :]
# Out:
#    S_borough             S_neighborhood  \
# 1          2  BAYCHESTER
# 2          2  BAYCHESTER
#
#                       S_building_class_category S_block S_lot  \
# 1  01  ONE FAMILY HOMES                           04715  0022
# 2  01  ONE FAMILY HOMES                           04715  0056
#
#                                    S_address  S_apt_number  S_zipcode  \
# 1  1156 EAST 221 STREET                                       10469.0
# 2  3840 LACONIA AVENUE                                        10469.0
#
#    S_residential_units  S_commercial_units  S_total_units  S_land_sqft  \
# 1                  1.0                 0.0            1.0       1842.0
# 2                  1.0                 0.0            1.0       2320.0
#
#    S_gross_sqft  S_year_built  S_tax_class_at_sale S_building_class_at_sale  \
# 1        1744.0        1950.0                    1                       A5
# 2        1690.0        1950.0                    1                       A9
#
# ...

# %%
hmm.groupby(['bbl','year']).bbl.size()
# Out:
# bbl         year
# 1000070038  2015/16    1
# 1000110010  2012/13    1
# 1000110014  2013/14    2
#             2015/16    1
#             2017/18    1
#                       ..
# 5080500017  2014/15    1
# 5080500019  2015/16    1
# 5080500031  2017/18    1
# 5080500060  2012/13    2
# 5080500083  2017/18    1
# Name: bbl, Length: 278040, dtype: int64

# %%
moon.groupby(['bbl','year']).bbl.size()
# Out:
# bbl         year
# 1000070038  2015/16    1
# 1000110014  2013/14    2
#             2015/16    1
#             2017/18    1
#             2018/19    2
#                       ..
# 5080500017  2014/15    1
# 5080500019  2015/16    1
# 5080500031  2017/18    1
# 5080500060  2012/13    1
# 5080500083  2017/18    1
# Name: bbl, Length: 261004, dtype: int64

# %%
twetwev_hmm, twetwev_moon = hmm[hmm.year == '2012/13'], moon[moon.year == '2012/13']
twetwev_hmm.S_sale_date.isin(twetwev_moon.S_sale_date).sum()
# Out:
# 23708

# %%
twetwev_hmm.S_sale_date.min()
# Out:
# Timestamp('2012-07-02 00:00:00')

# %%
47780-29995
# Out:
# 17785

# %%
lost_data = hmm.iloc[().index, :]
lost_data
# Out:
#         S_borough             S_neighborhood  \
# 1               2  BAYCHESTER
# 6               2  BAYCHESTER
# 16              2  BAYCHESTER
# 21              2  BEDFORD PARK/NORWOOD
# 29              2  BEDFORD PARK/NORWOOD
# ...           ...                        ...
# 364607          5                    WOODROW
# 364608          5                    WOODROW
# 364609          5                    WOODROW
# 364610          5                    WOODROW
# 364611          5                    WOODROW
#
#                            S_building_class_category S_block S_lot  \
# 1       01  ONE FAMILY HOMES                           04715  0022
# 6       01  ONE FAMILY HOMES                           04803  0043
# 16      02  TWO FAMILY HOMES                           04978  0052
# 21      02  TWO FAMILY HOMES                           03343  0146
# 29      10  COOPS - ELEVATOR APARTMENTS                03311  0044
# ...                                              ...     ...   ...
# ...

# %%
len(~(hmm_sales_dates).isin(moon.S_sale_date))
# Out:
# 346827

# %%
len((hmm.bbl+hmm.year).isin(moon.bbl + moon.year))
# Out:
# 364612

# %%
len(hmm[(hmm.bbl+hmm.year).isin(moon.bbl + moon.year)])
# Out:
# 346827

# %%
hmm_sales_dates = hmm[(hmm.bbl+hmm.year).isin(moon.bbl + moon.year)].S_sale_date

# %%
346827 - 340540
# Out:
# 6287

# %%
moon.columns[18:21]
# Out:
# Index(['bbl', 'bbl_block', 'bbl_lot'], dtype='object')

# %%
moon.S_sale_price_per_unit
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-49-c81a18f31471> in <module>
# ----> 1 moon.S_sale_price_per_unit
#
# ~/anaconda3/envs/myenv/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'S_sale_price_per_unit'

# %%
hmm.columns[18:21]
# Out:
# Index(['S_apt_2', 'S_sale_price_per_unit', 'bbl'], dtype='object')

# %%
364612 - 12808
# Out:
# 351804

# %%
pd_readpickl(merged-sales-valuation-dem.pkl')
