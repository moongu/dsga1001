# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os.path
import itertools
import datetime

from IPython.display import display
pd.options.display.max_columns = None
above = '../../../'

# %%
# Read in the final merge **change the name to the actual file once its done
data = pd.read_pickle(above + 'merged-sales-val-macro-dem.pkl')
# Columns to drop
drop = ["S_neighborhood", "S_building_class_category", "S_block", "S_lot", "S_address", "S_apt_number", 
        "S_total_units", "S_tax_class_at_sale", 
        "year", "v_bble", "v_boro", "v_block", "v_lot", "v_owner", "v_bldgcl", "v_taxclass", "v_avland", "v_avtot" ]
data
# Out:
#         S_borough             S_neighborhood  \
# 0               2  BATHGATE
# 1               2  BATHGATE
# 2               2  BAYCHESTER
# 3               2  BAYCHESTER
# 4               2  BAYCHESTER
# ...           ...                        ...
# 316591          5                    WOODROW
# 316592          5                    WOODROW
# 316593          5                    WOODROW
# 316594          5                    WOODROW
# 316595          5                    WOODROW
#
#                            S_building_class_category S_block S_lot  \
# 0       01  ONE FAMILY DWELLINGS                       03028  0025
# 1       01  ONE FAMILY DWELLINGS                       03046  0052
# 2       01  ONE FAMILY DWELLINGS                       04724  0006
# 3       01  ONE FAMILY DWELLINGS                       04750  0048
# 4       01  ONE FAMILY DWELLINGS                       04792  0012
# ...                                              ...     ...   ...
# ...

# %%
# Histogram of the sales vs 
def hist_col(data, col, b):
    data99_max = data[data[col] <= np.percentile(data[col],99)][col].max()
    plt.hist(data[col],bins=b, range=(0, np.percentile(data[col],99)))
    plt.xlabel(f'Price in % of {data99_max}')
    plt.ylabel("Count of units sold")
    plt.title('Histogram of total ' + col)
    plt.show()
hist_col(data, 'S_sale_price', 50)

# %%
hist_col(data, "S_land_sqft", 50)

# %%
hist_col(data, "S_gross_sqft", 50)

# %%
# Number of 0 values in sales S_land_sqft
print(((data.S_land_sqft) == 0).sum())
# Number of 0 values in valuation lotfront or lotdepth
print(((data.v_ltfront * data.v_ltdepth) == 0).sum())
# Where we have 0 values in either sales or valuation
miss_area = data[(data.S_land_sqft == 0) & ((data.v_ltfront * data.v_ltdepth) == 0)]
print(miss_area.shape[0])
# Out:
# 146684
# 48470
# 46087

# %%
# Histogram of sales with missing values for square footage
hist_col(miss_area, 'S_sale_price')

# %%
# Missing area by year
miss_area.groupby(miss_area.year).S_borough.count()
# Out:
# year
# 2012/13    4104
# 2013/14    8442
# 2014/15    7780
# 2015/16    7560
# 2016/17    8010
# 2017/18    7237
# 2018/19    2954
# Name: S_borough, dtype: int64

# %%
# Compare the square footage of the S_land_sqft and product of v_ltfront and v_ltdepth
np.abs((data.S_land_sqft - (data.v_ltfront * data.v_ltdepth))).sum()/(data.S_land_sqft.sum())
# Out:
# 8.835656733632018

# %%
# Cases where S_building_class_at_sale does not line up with v_bldgcl
data[data.S_building_class_at_sale != data.v_bldgcl].shape
# Out:
# (1322, 95)

# %%
# What is the difference between the two tax classes?
data.groupby(data.S_tax_class_at_sale).count()
# Out:
#                      S_borough  S_neighborhood  S_building_class_category  \
# S_tax_class_at_sale
# 1                       155249          155249                     155249
# 2                       161347          161347                     161347
#
#                      S_block   S_lot  S_address  S_apt_number  S_zipcode  \
# S_tax_class_at_sale
# 1                     155249  155249     155249        155249     155249
# 2                     161347  161347     161347        161347     161347
#
#                      S_residential_units  S_commercial_units  S_total_units  \
# S_tax_class_at_sale
# 1                                 155249              155249         155249
# 2                                 161347              161347         161347
#
#                      S_land_sqft  S_gross_sqft  S_year_built  \
# S_tax_class_at_sale
# 1                         155249        155249        155249
# 2                         161347        161347        161347
#
# ...

# %%
data[data.S_commercial_units > 0]
# Out:
#         S_borough             S_neighborhood  \
# 34              2  BEDFORD PARK/NORWOOD
# 36              2  BEDFORD PARK/NORWOOD
# 55              2  BRONXDALE
# 102             2  FORDHAM
# 108             2  HIGHBRIDGE/MORRIS HEIGHTS
# ...           ...                        ...
# 316322          5               NEW BRIGHTON
# 316334          5                   NEW DORP
# 316335          5                   NEW DORP
# 316494          5                  STAPLETON
# 316500          5                  STAPLETON
#
#                            S_building_class_category S_block S_lot  \
# 34      08  RENTALS - ELEVATOR APARTMENTS              03320  0028
# 36      08  RENTALS - ELEVATOR APARTMENTS              03344  0082
# 55      14  RENTALS - 4-10 UNIT                        04566  0046
# 102     08  RENTALS - ELEVATOR APARTMENTS              03162  0029
# 108     07  RENTALS - WALKUP APARTMENTS                02868  0001
# ...

# %%
# Why are these values not only the commercial building class codes?
data[data.S_commercial_units > 0].v_bldgcl.unique()
# Out:
# array(['D1', 'D7', 'S9', 'C7', 'S3', 'S2', 'S1', 'S4', 'S5', 'D6', 'S0',
#        'C4', 'C5', 'C6', 'D2', 'B1', 'C1', 'C3', 'C0', 'D9', 'D4', 'C9',
#        'D3', 'D5', 'D8', 'B3', 'C2', 'A5', 'A9', 'C8', 'D0', 'B2', 'R4',
#        'B9', 'A3', 'A4', 'A1', 'R1'], dtype=object)

# %%
data.describe()
# Out:
#            S_borough      S_zipcode  S_residential_units  S_commercial_units  \
# count  316596.000000  316596.000000        316596.000000       316596.000000
# mean        2.939339   10824.100488             2.007445            0.044100
# std         1.326327     602.214148            25.818895            0.364818
# min         1.000000       0.000000             0.000000            0.000000
# 25%         2.000000   10302.000000             0.000000            0.000000
# 50%         3.000000   11208.000000             1.000000            0.000000
# 75%         4.000000   11360.000000             2.000000            0.000000
# max         5.000000   11697.000000          8759.000000           46.000000
#
#        S_total_units   S_land_sqft  S_gross_sqft   S_year_built  \
# count  316596.000000  3.165960e+05  3.165960e+05  316596.000000
# mean        2.054710  2.350672e+03  1.974196e+03    1843.880637
# std        25.980013  1.526579e+04  2.761232e+04     436.114871
# ...

# %%
sales_01 = np.percentile(data['S_sale_price'],1)
sales_99 = np.percentile(data['S_sale_price'],99)
sales_01
# Out:
# 10.0
